# %%
import pandas as pd

train = pd.read_csv("/Users/timwalther/Documents/GitHub/house-prices-ml-pipeline-1/data/raw/train.csv")
test = pd.read_csv("/Users/timwalther/Documents/GitHub/house-prices-ml-pipeline-1/data/raw/test.csv")

train.shape
train.columns
train["SalePrice"].describe()
train.isna().mean().sort_values(ascending=False).head(15)
# Out:
# PoolQC          0.995205
# MiscFeature     0.963014
# Alley           0.937671
# Fence           0.807534
# MasVnrType      0.597260
# FireplaceQu     0.472603
# LotFrontage     0.177397
# GarageYrBlt     0.055479
# GarageCond      0.055479
# GarageType      0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# BsmtFinType2    0.026027
# BsmtExposure    0.026027
# BsmtQual        0.025342
# dtype: float64
